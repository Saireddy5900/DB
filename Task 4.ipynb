# %%
a = 20
b = 12

result = a + b
print(result)

# %%
a = 8
b = 3

if a > b:
    print(a)
else:
    print(b)

# %%
import math
n = 6
print(math.factorial(n))

# %%
arr = [12, 3, 4, 15]
ans = sum(arr)
print('Sum:', ans)

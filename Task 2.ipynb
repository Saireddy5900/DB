# %%
# %sql
select * from workspace.default.organizations_100

# %%
# %sql
select * from workspace.default.organizations_100 where Country = 'China'

# %%
# %sql
select * from workspace.default.organizations_100 where Name ='Mayer Group'

# %%
# %sql
select * from workspace.default.organizations_100 where Industry = 'Mental Health Care'
